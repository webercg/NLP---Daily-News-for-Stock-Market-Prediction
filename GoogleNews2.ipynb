# %% [markdown]
# <a href="https://colab.research.google.com/github/webercg/NLP---Daily-News-for-Stock-Market-Prediction/blob/main/GoogleNews2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install GoogleNews
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 288 kB 5.6 MB/s
# ...

# %%
#IMPORTANDO BIBLIOTECAS E CRIANDO FUNÇÃO P LOOP DE DATAS 
from datetime import timedelta, date
import pandas as pd
from GoogleNews import GoogleNews

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %%
#ESCOLHA DE VARIÁVEIS 
#data em formato YYYY-D-M
start_date = date(2022, 5, 5)
end_date = date(2022, 5, 10)
termo = 'petrobras'

# %%
googlenews = GoogleNews()
googlenews.clear()
googlenews.set_lang('pt')
googlenews.set_encode('utf-8')
googlenews.search(termo)
#df = pd.DataFrame(columns=['date', 'desc','link','media','title'])
df = pd.DataFrame()
for single_date in daterange(start_date, end_date):
    dt = single_date.strftime("%m-%d-%Y")
    googlenews.set_time_range(dt,dt)
    result = googlenews.result()
    df1 = pd.DataFrame(result)
    df = df.append(df1, ignore_index=True)

# %%
df.drop(['datetime', 'img'], axis = 1, inplace = True) 
df
# Out:
#                                                 title  \
# 0   Petrobras: ações valorizam após anúncio sobre ...
# 1   Sem coragem para enfrentar preço dos combustív...
# 2   Petrobras (PETR4): 3 cenários possíveis para a...
# 3   Paes de Andrade indica número 2 da Casa Civil ...
# 4   DOU traz recomendação do PPI de inclusão da Pe...
# 5   Ibovespa patina perto de zero dividido entre a...
# 6   Esquenta dos mercados: Bolsas lá fora caem com...
# 7   Conselho publica recomendação de incluir Petro...
# 8   Governo vai indicar número 2 da Casa Civil par...
# 9   Bolsonaro propõe compensar estados para zerar ...
# 10  Petrobras: ações valorizam após anúncio sobre ...
# 11  Sem coragem para enfrentar preço dos combustív...
# 12  Petrobras (PETR4): 3 cenários possíveis para a...
# 13  Paes de Andrade indica número 2 da Casa Civil ...
# 14  DOU traz recomendação do PPI de inclusão da Pe...
# 15  Ibovespa patina perto de zero dividido entre a...
# ...

# %%
#df.to_csv('News_Petro_Jun_Out_21v2.csv',encoding='utf-8')
