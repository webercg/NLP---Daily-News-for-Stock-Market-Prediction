# %%
import pandas as pd

# %%
arq = 'https://raw.githubusercontent.com/webercg/NLP---Daily-News-for-Stock-Market-Prediction/main/datasets/Nov-2021.csv'
df = pd.read_csv(arq, sep='|')

# %%
df['date'].value_counts()
# Out:
# 01/11/2021    10
# 02/11/2021    10
# 27/11/2021    10
# 26/11/2021    10
# 25/11/2021    10
# 24/11/2021    10
# 22/11/2021    10
# 19/11/2021    10
# 18/11/2021    10
# 17/11/2021    10
# 16/11/2021    10
# 15/11/2021    10
# 30/11/2021    10
# 12/11/2021    10
# 11/11/2021    10
# 10/11/2021    10
# 09/11/2021    10
# 08/11/2021    10
# 05/11/2021    10
# 04/11/2021    10
# 03/11/2021    10
# 06/11/2021     9
# 13/11/2021     7
# 20/11/2021     6
# 28/11/2021     5
# 07/11/2021     4
# 14/11/2021     4
# Name: date, dtype: int64

# %%
df
# Out:
#                                                  title            media  \
# 0    Após comentários, Petrobras nega antecipação d...            Exame
# 1    Petrobras diz que não antecipa decisões de rea...   Agência Brasil
# 2    Bolsonaro quer usar dividendos da Petrobras pa...  Valor Econômico
# 3    Bolsa sobe com ajuda de Vale e Petrobras, mas ...          O Globo
# 4    Entenda por que as ações da Petrobras subiram ...       CNN Brasil
# ..                                                 ...              ...
# 240  Não vamos manter essa política de preços da Pe...     UOL Economia
# 241  Petrobras confirma previsão de US$ 60 bi a US$...       CNN Brasil
# 242  Petrobras faz nova oferta de reajuste do gás n...  Valor Econômico
# 243  Importação de gasolina no Brasil dobrou em um ...    Olhar Digital
# 244  Jornais | Petrobras avança no gás natural e pr...  EuQueroInvestir
#
#            date                                               desc
# ...
